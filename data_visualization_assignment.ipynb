# %% [markdown]
# # Data Visualization Assignment

# %% [markdown]
# In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D 
from sklearn import decomposition 
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
iris.data.shape
# Out:
# (150, 4)

# %%
iris.target.shape
# Out:
# (150,)

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
PCA = decomposition.PCA(n_components = 3)
reduced_data = PCA.fit_transform(iris.data)

# %%
iris.target_names[iris.target[149]]
# Out:
# 'virginica'

# %%
figure=plt.figure(figsize=(10,7))
#axes =figure.add_subplot(projection='3d')
axes =  Axes3D(figure, elev=-150, azim=110)
#for i in range(len(iris.target)):
dots = axes.scatter(reduced_data[:,0], reduced_data[:,1], reduced_data[:,2], c=iris.target, edgecolor='k', s=50)
colorbar = plt.colorbar(dots)
axes.set_title("Iris Dataset - 3 PCA directions")
axes.set_xlabel("PCA 1")
axes.w_xaxis.set_ticklabels([])
axes.set_ylabel("PCA - 2")
axes.w_yaxis.set_ticklabels([])
axes.set_zlabel("PCA - 3")
axes.w_zaxis.set_ticklabels([])
plt.show()
